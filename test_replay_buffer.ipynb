# %% [markdown]
# # Test Replay Buffer

# %%
# %run replay_buffer

# %% [markdown]
# ## Initialization

# %%
frameShape = (2, 3) # small dummy shape
foo = ReplayBuffer(3, frameShape)

# %%
foo
# Out:
# self.size = 3
# self.shape = (2, 3)
# self.index = 0

# %% [markdown]
# ## storeTransition

# %% [markdown]
# Overwriting the oldest entries takes place.

# %%
for i in range(0, 5):
    phi = torch.randn(frameShape)
    action = torch.randint(high = 4, size = (1,)) # must be a tuple
    reward = torch.randint(high = 100, size = (1,))
    nextState = torch.randn(frameShape)
    transition = (phi, action, reward, nextState)
    foo.storeTransition(transition)

    print(f"---\n{foo.index = }\nReward:\t{foo.reward}")
# Out:
# ---
# foo.index = 0
# Reward:	tensor([93., 63., 12.])
# ---
# foo.index = 1
# Reward:	tensor([54., 63., 12.])
# ---
# foo.index = 2
# Reward:	tensor([54.,  6., 12.])
# ---
# foo.index = 0
# Reward:	tensor([54.,  6., 59.])
# ---
# foo.index = 1
# Reward:	tensor([19.,  6., 59.])

# %% [markdown]
# ## sample

# %% [markdown]
# Proof of principle.

# %%
asdf = torch.randn(5)
asdf
# Out:
# tensor([ 0.6691, -0.0332,  1.3066,  0.4105, -1.0266])

# %%
asdf2 = torch.randperm(n = 5)
asdf2
# Out:
# tensor([2, 3, 4, 1, 0])

# %%
asdf[asdf2]
# Out:
# tensor([-2.2256, -0.6780,  0.1976, -0.8688, -0.0258])

# %% [markdown]
# Use of sample.

# %%
phi, action, reward, nextState = foo.sample(1)
labels = "phi,action,reward,nextState"

for i,j in zip([phi, action, reward, nextState], labels.split(',')) :
    print(j, i)
# Out:
# phi tensor([[[-0.9590, -1.9910,  0.4891],
#          [-0.3414, -1.6896, -0.0722]]])
# action tensor([0.])
# reward tensor([65.])
# nextState tensor([[[-0.5649, -1.7235,  1.0847],
#          [ 1.6714, -0.5161,  2.6011]]])
