# %%
# %run DQNAgent

# %%
basicMovement = [['A'],
                 ['right'], ['right', 'A'], ['right', 'B'],
                 ['NOOP']]

foo = DQNAgent(rom = 'v0',
               bufferCapacity = 25_000,
              buttonList = basicMovement)
# Out:
# Initializing gymnasium environment (v0)
# C:\Users\user\pytorch_env\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment SuperMarioBrosRandomStages-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.deprecation(
# Setting up Replay Buffer
# Setting up DQN
# Setting up output folders...
# Saving outputs to : ./results/2025_12_10__21_02_55/
# Saving configuration to: ./results/2025_12_10__21_02_55/config.json
# Saving log to: ./results/2025_12_10__21_02_55/log.csv

# %%
foo.runEpisodes(150)
# Out:
# Starting episode 0
# Starting episode 1
# Starting episode 2
# Starting episode 3
# Starting episode 4
# Starting episode 5
# Starting episode 6
# Starting episode 7
# Starting episode 8
# Starting episode 9
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 foo.runEpisodes(150)
#
# File ~\Documents\GitHub\SMB_RL\3_revised_attempt\DQNAgent.py:403, in DQNAgent.runEpisodes(self, numEpisodes)
#     400 time = datetime.datetime.now()
#     402 # write results to CSV
# --> 403 with open(self.logPath, "a") as f:
#     404     f.write(f"{self.episode},{total_reward},{x_pos},{game_time},{flag_get},{loss},{self.epsilon},{steps},{truncated},{stuck},{course},{time}\n")
#     406 if i % 1_000 == 0 or i == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/2025_12_10__21_02_55/log.csv'

# %%
foo

# %%
foo.Q
# Out:
# Input shape: (12, 100, 100)
# First FC layer number of nodes: 5184
# Feature extractor output: (channels=64, height=9, width=9)
# Flattened size: 5184
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(12, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (1): Flatten(start_dim=1, end_dim=-1)
#   (2): Sequential(
#     (0): Linear(in_features=5184, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %%
foo.D
# Out:
# self.size = 25000
# self.shape = (12, 100, 100)
# self.index = 203
# self.action[0] = tensor(1, dtype=torch.int32)
